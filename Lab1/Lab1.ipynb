# %% [markdown]
# # Lab 1 Setup Verification
#
# This notebook demonstrates that the `ML` conda environment is set up with the required libraries:
# - numpy
# - pandas
# - scikit-learn
# - Jupyter Notebook

# %% [markdown]
# ## 1. Anaconda Installation
#
# <img src="https://raw.githubusercontent.com/shamshad-ansari/CSCI380/refs/heads/main/Lab1/screenshots/Installation.png" width="600">

# %% [markdown]
# ## 2. ML Environment Active
#
# <img src="https://raw.githubusercontent.com/shamshad-ansari/CSCI380/refs/heads/main/Lab1/screenshots/MLEnv.png" width="600">

# %% [markdown]
# ## 3. Installed Libraries
#
# <img src="https://raw.githubusercontent.com/shamshad-ansari/CSCI380/refs/heads/main/Lab1/screenshots/Libraries.png">
